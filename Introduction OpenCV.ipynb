# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.21.5)

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.1.2

# %%
# %cd /content/drive/MyDrive/MaaouiTP0
# %ls
X=cv2.imread('miami-heat-logo.png')
print(X.shape)
#cv2.imshow('Image',X)
from google.colab.patches import cv2_imshow
cv2_imshow(X)
# Out:
# /content/drive/MyDrive/MaaouiTP0
# miami-heat-logo.png
# (524, 708, 3)
# <PIL.Image.Image image mode=RGB size=708x524 at 0x7F48107A0F50>

# %%
Grey=cv2.cvtColor(X,cv2.COLOR_BGR2GRAY)
cv2_imshow(Grey)
print(Grey.shape)
cv2.imwrite('Hedi.jpg',Grey)
# Out:
# <PIL.Image.Image image mode=L size=708x524 at 0x7F4810719B90>
# (524, 708)
# True
